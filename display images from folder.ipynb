# %%
# import the modules
import os
from os import listdir

# get the path/directory
folder_dir = "C:/Users/User/Desktop/images"
for images in os.listdir(folder_dir):

	# check if the image ends with png
	if (images.endswith(".png")):
		print(images)
# Out:
# black.png
# bottle.png
# cat_damaged.png
# cat_mask.png
# crop.png
# dog.png
# dog1.png
# filter.png
# frame.png
# oimage.png
# p4.png
# p5.png
# pdf.png
# shapes.png
# watermark.png
# ximage.png

# %%
# import the modules
import os
from os import listdir

# get the path/directory
folder_dir = "C:/Users/User/Desktop/images"
for images in os.listdir(folder_dir):
		print(images)
# Out:
# 1.jfif
# black.png
# bottle.png
# cat_damaged.png
# cat_mask.png
# crop.png
# dog.jpg
# dog.png
# dog1.png
# filter.png
# flower 1.jpg
# food.jpg
# food1.jpg
# frame.jpeg
# frame.png
# mobile.jfif
# nature.jpg
# oimage.png
# p1.jfif
# p2.jpg
# p3.jpg
# p4.png
# p5.png
# p6.jpg
# pdf.png
# rabbit.jpg
# red-roses.jpg
# red.jpg
# shapes.png
# shh.jpeg
# text.jpeg
# tq.jpg
# txt.jpeg
# txt1.jpg
# txt2.jpg
# watermark.png
# ximage.png

# %%
#import necessary packages 
import cv2 
import os 
import glob 
import matplotlib.pyplot as plt 
# %matplotlib inline 
 
#Set the path where images are stored 
img_dir = "C:/Users/User/Desktop/images" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = cv2.imread(f1) 
    data.append(img) 
    plt.figure() 
    plt.imshow(img)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5792/2289939011.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
